# %%
"""Quiz Homework."""

# %% [markdown]
# 1) Как понять, что домашка пришла?
# Нужно зайти в телеграм сообщество и следить за сообщением данного формата: "@name прими пул."
# 2) Как принять домашку?
# Нужно зайти в GitHub Desktop, нажать на Fetch Origin, затем перейти во вкладку history и искать комиты.
# 3) Зачем нужна кнопка history и какие функции появляются при нажатии правой кнопки мыши на коммит? Кнопка history нужна для того, чтобы смотреть и искать комиты. При нажатии правой кнопки мыши на коммит появляется выбор Checkout commit, Reorder commit, Revert changes in commit и т.д.
# 3.1) Где брать ссылку на коммит? куда её отправлять? Visual Studio Code.
# 4) Что такое файл лога? Логирование урока. Файл лога это тот файл, где будет хранится информация о том, что мы выполнили по домашней работе.
# 4.1) Когда нужно его пушить? После того, как отреагировал на изменения GitHub, обязательно заполняем summary, нажимаем на commit to main и можно пушить.
# 5) Что такое интерпритатор? это программа, которая читает и запускает наш код.
# 6) Где можно выбрать интерпритатор? В Visual Studio Code его можно выбрать в строчке на самом верху, нажав на Python Environments, затем (base Python 3.10.9).
# 7) Что такое модуль? модуль это файл .py или .ipynb
# 8) Как создать и отправить коммит? Необходимо заполнить summary название коммита, затем нажимаем на commit to main.
# 9) Как посмотреть что коммит точно отправлен и находится в github? нужно зайти в history, нажать на правую кнопку мышки, затем выбрать view on github.
# 10) Какая команда показывает что код не прошёл проверки на ошибки? pre-commit run --all-files
# 10.1) Напишите список линтеров которые используются для проверки кода и дайте их краткую характеристику. Pylint - линтер для пайтон, исправляет синтаксические ошибки. Pydocstyle - разбивает по категориям найденные ошибки. Flake8 - проверяет стилистические проблемы.
# 11) Как узнать какой именно линтер не прошёл проверку? нужно ввести команду pre-commit run --all-files и смотреть какие линтера отоброжают статус failed.
# 12) Линтер Pylint видит markdown? нет
# 13) Номер ячейки в терминале и номер ячейки в vs code может отличаться? в каком случае? да, могут отличаться, если ошибка находится в ячейке после markdown.
# 14) Где посмотреть номер ячейки в vscode? внизу, она выглядит так: cell 3 of 3.
# 15) В каком формате ipynb отправляется в гитхаб? причём здесь JSON? ipynb — это файл Jupyter Notebook. GitHub отображает все данные в формате JSON.
# 16) Где посмотреть в какой ячейке ошибка? ctrl + F
# 17) Как запустить терминал? терминал можно открыть через меню ... > Терминал > New Terminal.
# 18) Что такое линтер? Линтер это инструмент, который анализирует код на наличие ошибок
# 19) В какой сайт нужно вставлять код ошибки если ошибка связана с pylint? Pylint 3.2.6
# 20) Секция pydocstyle в большинстве случае автоматический закрывается после исправления ошибок в каком линтере?  по Pylint.
# 21) Что такое описание модуля? Оно должно отражать информацию о том что находится в модуле? Описание модуля - это информация находится в модуле. да.
# 21) С какой  git команды начинается утро программиста?
# 22) После внесения изменений в файлах, кнопка open in vs code пропадает в кошке, как по другому открыть vs code из кошки? нужно нажать на правую кнопку мышки current repository затем нажать на open in VS code
# 23) Что такое stash?  В случае если двое или несколько человек работают в одном файле появляется stash и просит сохранить временные изменения в буфер обмена.
#   Общее объяснение концепции. Stash changes появляется когда работа проводится в двух файлах: на локальном и из интернета и github просит сохранить временные изменения в буфер обмена и принимаются изменения из интернета.
# 23.1) Как сохранить стэш? Нужно нажать на stashed changes и восстановить локальный буфер(Restore), иначе изменения не будут сохранены. Далее открыть файл в Visual Studio Code и нажать на Accept Current Changes, далее complete merge.
